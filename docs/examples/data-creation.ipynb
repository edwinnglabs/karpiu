# %% [markdown]
# # Data Creation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from karpiu.simulation import make_mmm_daily_data

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
N_STEPS = 365 * 3
COEFS = [0.03, 0.05, 0.028, 0.01, 0.03]
CHANNELS = ['tv', 'radio', 'social', 'promo', 'search']
LOC = np.array([10000, 5000, 3000, 2000, 850])
SCALE = np.array([5000,3000, 1000, 550, 500])
SCALABILITY =  np.array([1.1, 0.75, 1.3, 1.5, 0.9])
SEED = 2022
START_DATE = '2019-01-01'

# %%
from karpiu.simulation import make_adstock_matrix

# %%
adstock_matrix = make_adstock_matrix(
    n_steps=28, 
    peak_step = np.array([10, 8, 5, 3, 2]),
    left_growth = np.array([.05, .08, .1, .5, .75]),
    right_growth = np.array([-.03, -0.6, -0.5, -.1, -.25]),
)

# %%
adstock_matrix
# Out:
# array([[2.90677144e-02, 3.05211001e-02, 3.20471551e-02, 3.36495128e-02,
#         3.53319885e-02, 3.70985879e-02, 3.89535173e-02, 4.09011932e-02,
#         4.29462528e-02, 4.50935655e-02, 4.50935655e-02, 4.37407585e-02,
#         4.24285357e-02, 4.11556797e-02, 3.99210093e-02, 3.87233790e-02,
#         3.75616776e-02, 3.64348273e-02, 3.53417825e-02, 3.42815290e-02,
#         3.32530831e-02, 3.22554907e-02, 3.12878259e-02, 3.03491912e-02,
#         2.94387154e-02, 2.85555540e-02, 2.76988873e-02, 2.68679207e-02],
#        [7.41124952e-02, 8.00414948e-02, 8.64448144e-02, 9.33603996e-02,
#         1.00829232e-01, 1.08895570e-01, 1.17607216e-01, 1.27015793e-01,
#         1.27015793e-01, 5.08063172e-02, 2.03225269e-02, 8.12901075e-03,
#         3.25160430e-03, 1.30064172e-03, 5.20256688e-04, 2.08102675e-04,
#         8.32410700e-05, 3.32964280e-05, 1.33185712e-05, 5.32742848e-06,
#         2.13097139e-06, 8.52388557e-07, 3.40955423e-07, 1.36382169e-07,
#         5.45528677e-08, 2.18211471e-08, 8.72845883e-09, 3.49138353e-09],
#        [1.10701520e-01, 1.21771672e-01, 1.33948839e-01, 1.47343723e-01,
#         1.62078095e-01, 1.62078095e-01, 8.10390476e-02, 4.05195238e-02,
#         2.02597619e-02, 1.01298809e-02, 5.06494047e-03, 2.53247024e-03,
#         1.26623512e-03, 6.33117559e-04, 3.16558780e-04, 1.58279390e-04,
#         7.91396949e-05, 3.95698474e-05, 1.97849237e-05, 9.89246186e-06,
#         4.94623093e-06, 2.47311546e-06, 1.23655773e-06, 6.18278866e-07,
#         3.09139433e-07, 1.54569717e-07, 7.72848583e-08, 3.86424291e-08],
#        [3.90095787e-02, 5.85143681e-02, 8.77715522e-02, 8.77715522e-02,
#         7.89943969e-02, 7.10949573e-02, 6.39854615e-02, 5.75869154e-02,
#         5.18282238e-02, 4.66454015e-02, 4.19808613e-02, 3.77827752e-02,
#         3.40044977e-02, 3.06040479e-02, 2.75436431e-02, 2.47892788e-02,
#         2.23103509e-02, 2.00793158e-02, 1.80713842e-02, 1.62642458e-02,
#         1.46378212e-02, 1.31740391e-02, 1.18566352e-02, 1.06709717e-02,
#         9.60387451e-03, 8.64348706e-03, 7.77913836e-03, 7.00122452e-03],
#        [1.02605680e-01, 1.79559940e-01, 1.79559940e-01, 1.34669955e-01,
#         1.01002466e-01, 7.57518497e-02, 5.68138873e-02, 4.26104154e-02,
#         3.19578116e-02, 2.39683587e-02, 1.79762690e-02, 1.34822018e-02,
#         1.01116513e-02, 7.58373849e-03, 5.68780387e-03, 4.26585290e-03,
#         3.19938968e-03, 2.39954226e-03, 1.79965669e-03, 1.34974252e-03,
#         1.01230689e-03, 7.59230167e-04, 5.69422625e-04, 4.27066969e-04,
#         3.20300227e-04, 2.40225170e-04, 1.80168878e-04, 1.35126658e-04]])

# %%
df, scalability_df = make_mmm_daily_data(    
    coefs=COEFS,
    channels=CHANNELS,
    features_loc=LOC,
    features_scale=SCALE,
    scalability=SCALABILITY,
    n_steps=N_STEPS,
    seed=SEED,
)

# %%
df.head(3)
# Out:
#         date  sales       tv   radio  social   promo  search
# 0 2019-01-01  475.0   9998.0  4176.0     0.0     0.0   992.0
# 1 2019-01-02  785.0  13805.0     0.0  3541.0     0.0  1039.0
# 2 2019-01-03  786.0   9549.0     0.0  4143.0  1156.0   419.0

# %%
scalability_df.head(3)
# Out:
#   regressor  scalability
# 0        tv         1.10
# 1     radio         0.75
# 2    social         1.30

# %%
fig, ax = plt.subplots(1, 1, figsize=(16, 8))
ax.plot(data['sales'].values);

# %%
# df.to_csv('data.csv', index=False)
# scalability_df.to_csv('scalability_df.csv', index=False)
